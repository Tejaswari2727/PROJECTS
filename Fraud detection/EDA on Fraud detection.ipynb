# %% [markdown]
# # <h1 align="center"> <font color = blue>EDA on  FRAUD DETECTION Dataset</h1></font>

# %% [markdown]
# **Exploratory Data Analysis (EDA)** is a process for examining datasets to understand their structure, patterns, and key characteristics before building models.<br>
#
#
# The typical steps include in the data analysis process are:
#
#
# **1. Data Collection:** Collect the data and import the dataset into a Jupyter Notebook.
#
#
# **2. Data Inspection/Exploration:**
#
# - Check data dimensions (rows, columns)
# - View data summary (head, tail, info, describe)
#
#
#
# **3. Data Cleaning:**
#
#
# - Handle missing values (drop, fill)
# - Handle outliers (detect, correct, remove)
# - Data normalization (scaling, encoding)
#
#
# **4. Data Transformation:**
#
#
# - Convert data types (e.g., string to datetime).
#
# **5. Data Visualization:**
#
#
# - Plot distributions (histograms, box plots)
# - Visualize relationships (scatter plots, heatmaps)
# - Explore correlations.

# %% [markdown]
# # STEP-1:                                       DATA COLLECTION

# %% [markdown]
# PIP means [ Pip Installs Packages ]

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# We import Pandas to easily manage and analyze data, especially for handling tabular data like spreadsheets and CSV files. It provides powerful tools for data cleaning, manipulation, and exploration.
import pandas as pd  
# We import Matplotlib to create visualizations like plots, graphs, and charts in Python, helping to better understand and present data.
import matplotlib.pyplot as plt
# We import Seaborn to create more attractive and informative statistical visualizations, built on top of Matplotlib, with simplified syntax and additional features.
import seaborn as sns
# %matplotlib inline

# sk learn stands for sckit learn. It is a powerful machine learning model for pre-processing the data.
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv("C:/Users/batti/Jupyter notebooks/CSV.Jupyter notebook/creditcard_2023.csv")  # we set a path.
data  #CSV refers that comma separated value.
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %% [markdown]
# **observing data behaviour**<br>
# In the above dataset we have seen so many negative values this may appear for several reasons depending on the contex and the nature of the data.
#
#
# Here V1,V2.....v28 represent for the features or variables in the dataset.
#
#
# Class column should be contain 0's and 1's ---Then we consider 0 represent "No Fraud" and 1 represent "Fraud" for our simplicity.
#
#
# Here "Amount" column typically represents the monitor values of the transation.

# %% [markdown]
# #  STEP-2:  DATA INSPECTION/EXPLORATION

# %% [markdown]
# SHAPE() , HEAD() , TAIL() , INFO() , DESCRIBE()

# %%
# SHAPE func is used to find out the total no of ROWS and COLUMNS 
print(data.shape)
# Out:
# (568630, 31)

# %%
data.head()   #it prints the frst 5 columns
data.head(10)   #it prints the frst 10 columns
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
# 5   5  0.025302 -0.140514  1.191138 -0.707979  0.430490  0.458973  0.611050
# 6   6  1.016482 -0.397181  0.497868 -0.144463  0.331022  0.629243  0.431262
# 7   7 -0.051306 -0.007194  1.139941 -0.877880  0.684668  0.714326  0.892615
# 8   8 -0.130680 -0.349547  0.425786 -0.760444  1.702777  2.324816  0.568968
# 9   9  0.058419 -0.093507  1.117270 -0.735172  0.466111  0.332371  0.683425
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
data.head()   #it prints the last 5 columns
data.tail(10)   #it prints the last 10 columns
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 568620  568620 -1.604804  0.972534 -1.749894  1.920681 -1.856257 -0.219136
# 568621  568621 -0.739211  0.231882 -0.410204  0.511278  0.056859 -0.410720
# 568622  568622 -0.838047  0.362350 -0.061538  0.252811 -0.006436 -0.222957
# 568623  568623 -0.873853  0.780667 -0.418023  0.399324  0.522744  0.943413
# 568624  568624 -0.542349  0.585098 -0.547730  1.005465 -0.702046 -0.287417
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
#data.info  # it gives the complete information about the datset like datatupes,column names,non-null values..etc

# %%
data.describe()  # it generates descriptive statistics of  numerical columns in a dataset including count,mean,std,min,max,,etc
#such as mean, median, and standard deviation, to understand data distributions and variability.
#Means:The mean is the average of a set of numbers.
#median:The median is the middle value in a sorted set of numbers.
#Standard deviation: Standard deviation measures the amount of variation or spread in a set of numbers
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486122  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %%
data.dtypes  #it tells the datatypes of each and every column
# Out:
# id          int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
data.columns  # We use columns to organize data into specific categories or features, making it easier to analyze and understand.
# Out:
# Index(['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
#from sklearn.preprocessing import StandardScaler
#data[data.select_dtypes(include=['float64', 'int64']).columns] = StandardScaler().fit_transform(data.select_dtypes(include=['float64', 'int64']))
#print(data)

# %%
print(data.Class.unique()) #it print all the unique values which is present in Gender column
# Out:
# [0 1]

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis') 
# A heatmap is a visualization tool that uses color to represent the values of a dataset, making it easy to see patterns, correlations, and outliers.
# mainly it is used to find out the outliers

#The below graph shows that there is no outliers for the dataset. If the outliers or null values are there then it shows yellow colour points on that heatmap.so it indicate there is no outliers(null values).

# %%
data.isnull()  # it prints True if is there any [null] value otherwise it prints false.

# %%
data.isnull().sum() #it tells the no. of null values in each and every column

# %% [markdown]
# Here we understood that by  using functions. There is no null values so, no need to use drop() , fillna() methods..etc.

# %% [markdown]
# # STEP-4: DATA TRANSFORMATION

# %%
data.dtypes  
#dtypes refers to the data type of each column in a dataset, such as integer, float, or object, and it helps ensure proper data handling and analysis.
# Out:
# id          int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %% [markdown]
# Here we find out that the no. of values and their corresponding frequencies.<br>
# .value_counts()  ---used for displaying the column values and their corresponding frequencies<br>
# .value_counts().index  --- used for displaying only column values <br>
# .value_counts().values  ---used for displaying only corresponding frequencies<br>

# %%
data.Amount.value_counts()      
# value_counts() is a function which is used to count the occurrences of each unique value in a column, helping to understand the distribution of categorical data.
# Here we apply this  values_count() in amount column.
# Out:
# Amount
# 22239.17    5
# 11374.95    5
# 22481.52    5
# 14264.39    5
# 14773.74    5
#            ..
# 11128.21    1
# 20276.18    1
# 6245.40     1
# 22653.50    1
# 21493.92    1
# Name: count, Length: 506485, dtype: int64

# %%
Amount_name=data.Amount.value_counts().index   #I assign the Amount.value counts() to Amount_name to get a quick overview of the distribution of values in an Amount column of a dataset.
Amount_name # Here we used index to get overview of dtype in float values and name of the column and length of the column.
# Out:
# Index([22239.17, 11374.95, 22481.52, 14264.39, 14773.74, 23840.23,  11505.1,
#          282.35, 19073.22, 15842.27,
#        ...
#         1769.73, 19428.01,  7133.27, 14910.22, 11365.76, 11128.21, 20276.18,
#          6245.4,  22653.5, 21493.92],
#       dtype='float64', name='Amount', length=506485)

# %%
Amount_values=data.Amount.value_counts().values #Here "values" is to get thr occurrence.
Amount_values
# Out:
# array([5, 5, 5, ..., 1, 1, 1], dtype=int64)

# %%
data.V1.value_counts()
# Out:
# V1
# -1.704517    3539
# -2.459141    1399
# -1.161336     259
# -1.065576     255
# -1.522526     246
#              ...
# -0.272852       1
#  1.822123       1
#  0.556931       1
#  0.276802       1
# -0.795144       1
# Name: count, Length: 552035, dtype: int64

# %%
V1_count=data.V1.value_counts().index   #`V1_count` gets the unique values in `V1` sorted by their frequency.
V1_count
# Out:
# Index([-1.7045165212124185,  -2.459141149335575, -1.1613356376145123,
#         -1.065575815836581,  -1.522526483227019,  1.0430621137097136,
#        -1.0239578433718468, -1.5043433774345454, -1.6780711787361384,
#         -0.396577624435608,
#        ...
#        -0.2490382087470722, -0.0545085435880163, -0.3830436208688713,
#        -0.0759138927231048,   1.639604299162676, -0.2728520662257603,
#         1.8221233146628584,  0.5569307318395185,  0.2768023796023117,
#        -0.7951441654135905],
#       dtype='float64', name='V1', length=552035)

# %%
V1_Values=data.V1.value_counts().values #it gives the counts (frequencies) of each unique value in the `V1` column.
V1_Values
# Out:
# array([3539, 1399,  259, ...,    1,    1,    1], dtype=int64)

# %% [markdown]
# **Data Normalization**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_normalized = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
print(data_normalized)
data=data_normalized    #assigned the normalized variable data to our original variable
# Out:
#               id        V1        V2        V3        V4        V5        V6  \
# 0       0.000000  0.565091  0.911068  0.328143  0.597037  0.191428  0.462018
# 1       0.000002  0.782703  0.913159  0.216170  0.554606  0.194228  0.455582
# 2       0.000004  0.565157  0.902238  0.283790  0.551131  0.190372  0.476540
# 3       0.000005  0.584043  0.910345  0.284848  0.473588  0.193703  0.470699
# 4       0.000007  0.574494  0.916671  0.272150  0.552320  0.190981  0.457739
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625  0.999993  0.465034  0.920852  0.131948  0.718217  0.169934  0.456700
# 568626  0.999995  0.493503  0.915978  0.179994  0.574517  0.186428  0.451533
# 568627  0.999996  0.556121  0.919638  0.191875  0.602904  0.188163  0.449078
# 568628  0.999998  0.721873  0.910197  0.166548  0.589585  0.191454  0.440296
# 568629  1.000000  0.471723  0.927687  0.146429  0.653270  0.184315  0.433753
#
# ...

# %%
data  # All the normalized data has been updated in the original variable "data".
#Now, "data" variable having all Normalized data.
# Out:
#               id        V1        V2        V3        V4        V5        V6  \
# 0       0.000000  0.565091  0.911068  0.328143  0.597037  0.191428  0.462018
# 1       0.000002  0.782703  0.913159  0.216170  0.554606  0.194228  0.455582
# 2       0.000004  0.565157  0.902238  0.283790  0.551131  0.190372  0.476540
# 3       0.000005  0.584043  0.910345  0.284848  0.473588  0.193703  0.470699
# 4       0.000007  0.574494  0.916671  0.272150  0.552320  0.190981  0.457739
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625  0.999993  0.465034  0.920852  0.131948  0.718217  0.169934  0.456700
# 568626  0.999995  0.493503  0.915978  0.179994  0.574517  0.186428  0.451533
# 568627  0.999996  0.556121  0.919638  0.191875  0.602904  0.188163  0.449078
# 568628  0.999998  0.721873  0.910197  0.166548  0.589585  0.191454  0.440296
# 568629  1.000000  0.471723  0.927687  0.146429  0.653270  0.184315  0.433753
#
# ...

# %% [markdown]
# # STEP-5: DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('fivethirtyeight')
import seaborn

# %% [markdown]
# #target=data['Class'] #Here class is a target variable,using this target variable we will draw pie chart and bar chart from the dataset.
# #target

# %% [markdown]
# **BAR CHART**

# %% [markdown]
# A bar chart in EDA quickly shows and compares the frequency or size of different categories, making it easy to spot trends and differences.

# %%
#data.plot.bar(color=['skyblue', 'salmon'])
data['Class'].value_counts(normalize= True).plot(kind= 'bar') 
plt.xlabel("Class Distribution")
plt.ylabel("Frequency")
plt.title("Class balance")
# Out:
# Text(0.5, 1.0, 'Class balance')

# %%
# Select the target variable
target = data['Class']

# Count the occurrences of each class
class_counts = target.value_counts()

# Plotting the bar chart
plt.figure(figsize=(8,6))
class_counts.plot.bar(color=['skyblue', 'salmon'])
plt.title('Distribution of Fraud and Non-Fraud Transactions')
#plt.xlabel('Class')
plt.ylabel('Number of Transactions')
plt.xticks(ticks=[0, 1], labels=['Non-Fraud', 'Fraud'], rotation=0)
plt.show()

# %% [markdown]
# From this bar chart we can say that the 0 and 1 values are equal So, it means fraud and non-fraud are equall.

# %% [markdown]
# **PIE CHARTS**

# %% [markdown]
# A pie chart in EDA is used to visually represent the proportions of categorical data, making it easy to compare the relative sizes of different categories at a glance.

# %%
# Select the target variable
target = data['Class']

# Count the occurrences of each class
class_counts = target.value_counts()

# Plotting the pie chart
plt.figure(figsize=(8,8))
class_counts.plot.pie(autopct='%1.1f%%', startangle=140, labels=['Non-Fraud', 'Fraud'])
plt.title('Distribution of Fraud and Non-Fraud Transactions')
plt.ylabel('')  # Optional to remove the y-label
plt.show()

# %% [markdown]
# **BOX PLOT**

# %% [markdown]
# The boxplot shows that most data points range from about 100,000 to 400,000, with a median around 300,000. There are some high outliers, but the x-axis labels are unclear.

# %%
sns.boxplot(x='Class', y='Amount', data=data)
plt.title('Box Plot of Transaction Amounts by Class')
plt.show()

# %% [markdown]
# This boxplot compares transaction amounts between two classes (0 and 1). Both classes have similar distributions, with medians around 10,000 and most values falling between 5,000 and 20,000. There are no significant differences between the two classes in terms of transaction amounts.

# %% [markdown]
# **SCATTER PLOT**

# %% [markdown]
# Scatter plots in EDA help visualize relationships between two variables, detect outliers, and reveal patterns or trends in the data.

# %%
sns.scatterplot(x='Amount', y='V3', hue='Class', data=data)
plt.title('Scatter Plot of Amount vs. V1 by Class')
plt.show()
# The scatter plot shows the relationship between "Amount" and "V3," distinguishing two classes: 0 and 1 (likely non-fraudulent and fraudulent).

# %% [markdown]
# **CORRELATION HEATMAP**

# %% [markdown]
# A correlation heatmap specifically visualizes the correlation coefficients between variables in a dataset. The color intensity represents the strength of the correlation, with different colors indicating positive or negative relationships. It's a quick way to spot highly correlated features, which can guide feature selection and help identify potential issues like multicollinearity.

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set up the matplotlib figure
plt.figure(figsize=(22, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)

# Add a title
plt.title('Correlation Matrix of Features')

# Show the plot
plt.show()
